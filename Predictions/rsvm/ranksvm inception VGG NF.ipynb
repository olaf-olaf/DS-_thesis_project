# %%
import pandas as pd
import dlib

# %%
import pickle
win_set_train = pd.read_pickle('all features/NF_incep-vggface/NF_inception_resnet_vggface_win_set_train.pl')
los_set_train = pd.read_pickle('all features/NF_incep-vggface/NF_inception_resnet_vggface_los_set_train.pl')

# %%
win_set_test = pd.read_pickle('all features/NF_incep-vggface/NF_inception_resnet_vggface_win_set_test.pl') 
los_set_test = pd.read_pickle('all features/NF_incep-vggface/NF_inception_resnet_vggface_los_set_test.pl') 
los_set_test.head()
# Out:
#                                                    0  \
# 0  [[[[0.99635375]], [[0.2800763]], [[0.9080132]]...
# 1  [[[[0.7805182]], [[0.95616025]], [[0.5369174]]...
# 2  [[[[0.59677]], [[0.5697485]], [[0.61496675]], ...
# 3  [[[[0.59677]], [[0.5697485]], [[0.61496675]], ...
# 4  [[[[0.9737155]], [[0.97516936]], [[0.9996314]]...
#
#                                                    1  \
# 0  [[[[0.75416446]], [[0.08561997]], [[0.7660224]...
# 1  [[[[0.5746738]], [[0.7127113]], [[0.45439944]]...
# 2  [[[[0.40295824]], [[0.32106793]], [[0.5347975]...
# 3  [[[[0.40295824]], [[0.32106793]], [[0.5347975]...
# 4  [[[[0.7065966]], [[0.7304855]], [[0.81941974]]...
#
#                                                    2      3
# 0  [[[[0.7840042]], [[0.22174005]], [[0.82591856]...  False
# 1  [[[[0.70734286]], [[0.880798]], [[0.6587843]],...  False
# 2  [[[[0.6034232]], [[0.49305648]], [[0.7089673]]...  False
# 3  [[[[0.6034232]], [[0.49305648]], [[0.7089673]]...  False
# 4  [[[[0.7243814]], [[0.7652326]], [[0.90432405]]...  False

# %%
win_set_val = pd.read_pickle('all features/NF_incep-vggface/NF_inception_resnet_vggface_win_set_val.pl')
los_set_val = pd.read_pickle('all features/NF_incep-vggface/NF_inception_resnet_vggface_los_set_val.pl') 
# los_set_val
# Out:
#                                                      0  \
# 0    [[[[0.71906435]], [[0.22763297]], [[1.3515049]...
# 1    [[[[0.71906435]], [[0.22763297]], [[1.3515049]...
# 2    [[[[0.58531195]], [[0.7942919]], [[0.3299403]]...
# 3    [[[[1.078667]], [[0.78707194]], [[0.5030768]],...
# 4    [[[[0.891535]], [[0.49437937]], [[0.65005624]]...
# 5    [[[[1.078667]], [[0.78707194]], [[0.5030768]],...
# 6    [[[[0.891535]], [[0.49437937]], [[0.65005624]]...
# 7    [[[[1.078667]], [[0.78707194]], [[0.5030768]],...
# 8    [[[[0.891535]], [[0.49437937]], [[0.65005624]]...
# 9    [[[[0.4629934]], [[0.34171876]], [[0.560559]],...
# 10   [[[[0.4629934]], [[0.34171876]], [[0.560559]],...
# 11   [[[[1.2620397]], [[0.5191658]], [[0.5105253]],...
# 12   [[[[1.2620397]], [[0.5191658]], [[0.5105253]],...
# 13   [[[[0.55330867]], [[0.55095094]], [[0.48663867...
# 14   [[[[0.55330867]], [[0.55095094]], [[0.48663867...
# 15   [[[[0.77177227]], [[0.15939811]], [[0.3828547]...
# 25   [[[[0.74112916]], [[0.22768043]], [[0.65408176...  False
# 26   [[[[0.74549365]], [[0.3358587]], [[0.8631244]]...  False
# 27   [[[[0.46856606]], [[0.35564673]], [[0.50186694...  False
# 28   [[[[0.11419045]], [[0.13729183]], [[0.16716655...  False
# 29   [[[[0.74549365]], [[0.3358587]], [[0.8631244]]...  False
# ..                                                 ...    ...
# 593  [[[[0.25090063]], [[0.31967852]], [[0.3738555]...  False
# 594  [[[[0.7874969]], [[0.5692578]], [[0.54907113]]...  False
# 595  [[[[0.44379333]], [[0.42892057]], [[0.6153599]...  False
# 596  [[[[0.25090063]], [[0.31967852]], [[0.3738555]...  False
# 597  [[[[0.7874969]], [[0.5692578]], [[0.54907113]]...  False
# 598  [[[[0.75913423]], [[0.42116183]], [[0.28280807...  False
# 599  [[[[0.91481555]], [[0.85908544]], [[0.6224697]...  False
# 600  [[[[0.9991728]], [[1.2729609]], [[1.4985214]],...  False
# 601  [[[[0.69042516]], [[0.45809335]], [[0.6208524]...  False
# 602  [[[[0.46855637]], [[0.7809838]], [[0.32076928]...  False
# 603  [[[[0.33715641]], [[1.6435587]], [[1.1214223]]...  False
# 604  [[[[1.2413282]], [[0.19568408]], [[0.5339199]]...  False
# 605  [[[[0.33715641]], [[1.6435587]], [[1.1214223]]...  False
# 606  [[[[1.2413282]], [[0.19568408]], [[0.5339199]]...  False
# 607  [[[[1.2989361]], [[0.09533685]], [[0.34006298]...  False
# 608  [[[[0.6128846]], [[0.27004054]], [[0.9970967]]...  False
# 609  [[[[1.2989361]], [[0.09533685]], [[0.34006298]...  False
# 610  [[[[0.6128846]], [[0.27004054]], [[0.9970967]]...  False
# 611  [[[[1.2989361]], [[0.09533685]], [[0.34006298]...  False
# 612  [[[[0.6128846]], [[0.27004054]], [[0.9970967]]...  False
# 613  [[[[1.0094682]], [[1.3158702]], [[0.43695182]]...  False
# 614  [[[[0.94127727]], [[0.38757092]], [[0.48529458...  False
# 615  [[[[0.7940953]], [[0.73145247]], [[0.49791685]...  False
# 616  [[[[1.4417996]], [[0.43777242]], [[0.6950491]]...  False
# 617  [[[[0.13622192]], [[0.50476944]], [[0.5367161]...  False
# 618  [[[[1.4417996]], [[0.43777242]], [[0.6950491]]...  False
# 619  [[[[0.13622192]], [[0.50476944]], [[0.5367161]...  False
# 620  [[[[1.4417996]], [[0.43777242]], [[0.6950491]]...  False
# 621  [[[[0.13622192]], [[0.50476944]], [[0.5367161]...  False
# 622  [[[[0.3516246]], [[0.2502522]], [[0.86453575]]...  False
#
# [623 rows x 4 columns]

# %%
# %%time
import numpy as np
queries_train_l3 = dlib.ranking_pairs()
queries_train_l2 = dlib.ranking_pairs()
queries_train_l1 = dlib.ranking_pairs()

print("3")
for win_l3, los_l3 in zip(win_set_train[win_set_train.columns[0]],los_set_train[los_set_train.columns[0]]):
    data_pair = dlib.ranking_pair()
    shape_feat = win_l3.shape[1]
    win_l3 = win_l3.reshape(shape_feat,1)
    los_l3 = los_l3.reshape(shape_feat,1)
    data_pair.relevant.append(dlib.vector(win_l3))
    data_pair.nonrelevant.append(dlib.vector(los_l3))
    queries_train_l3.append(data_pair)
    
print("2")
for win_l2, los_l2 in zip(win_set_train[win_set_train.columns[1]],los_set_train[los_set_train.columns[1]]):
    data_pair = dlib.ranking_pair()
    shape_feat = win_l2.shape[1]
    win_l2 = win_l2.reshape(shape_feat,1)
    los_l2 = los_l2.reshape(shape_feat,1)
    data_pair.relevant.append(dlib.vector(win_l2))
    data_pair.nonrelevant.append(dlib.vector(los_l2))
    queries_train_l2.append(data_pair)    
    
print("1")  
for win_l1, los_l1 in zip(win_set_train[win_set_train.columns[2]],los_set_train[los_set_train.columns[2]]):
    data_pair = dlib.ranking_pair()
    shape_feat = win_l1.shape[1]
    win_l1 = win_l1.reshape(shape_feat,1)
    los_l1 = los_l1.reshape(shape_feat,1)
    data_pair.relevant.append(dlib.vector(win_l1))
    data_pair.nonrelevant.append(dlib.vector(los_l1))
    queries_train_l1.append(data_pair)


print("TEST")
queries_test_l3 = dlib.ranking_pairs()
queries_test_l2 = dlib.ranking_pairs()
queries_test_l1 = dlib.ranking_pairs()
print('3')
for win_l3, los_l3 in zip(win_set_test[win_set_test.columns[0]],los_set_test[los_set_test.columns[0]]):
    data_pair = dlib.ranking_pair()
    shape_feat = win_l3.shape[1]
    win_l3 = win_l3.reshape(shape_feat,1)
    los_l3 = los_l3.reshape(shape_feat,1)
    data_pair.relevant.append(dlib.vector(win_l3))
    data_pair.nonrelevant.append(dlib.vector(los_l3))
    queries_test_l3.append(data_pair)

print("2")
for win_l2, los_l2 in zip(win_set_test[win_set_test.columns[1]],los_set_test[los_set_test.columns[1]]):
    data_pair = dlib.ranking_pair()
    shape_feat = win_l2.shape[1]
    win_l2 = win_l2.reshape(shape_feat,1)
    los_l2 = los_l2.reshape(shape_feat,1)
    data_pair.relevant.append(dlib.vector(win_l2))
    data_pair.nonrelevant.append(dlib.vector(los_l2))
    queries_test_l2.append(data_pair)    
    
print("1")
    
for win_l1, los_l1 in zip(win_set_test[win_set_test.columns[2]],los_set_test[los_set_test.columns[2]]):
    data_pair = dlib.ranking_pair()
    shape_feat = win_l1.shape[1]
    win_l1 = win_l1.reshape(shape_feat,1)
    los_l1 = los_l1.reshape(shape_feat,1)
    data_pair.relevant.append(dlib.vector(win_l1))
    data_pair.nonrelevant.append(dlib.vector(los_l1))
    queries_test_l1.append(data_pair) 
    
    
    
print("val")
queries_val_l3 = dlib.ranking_pairs()
queries_val_l2 = dlib.ranking_pairs()
queries_val_l1 = dlib.ranking_pairs()
print('3')
for win_l3, los_l3 in zip(win_set_val[win_set_val.columns[0]],los_set_val[los_set_val.columns[0]]):
    data_pair = dlib.ranking_pair()
    shape_feat = win_l3.shape[1]
    win_l3 = win_l3.reshape(shape_feat,1)
    los_l3 = los_l3.reshape(shape_feat,1)
    data_pair.relevant.append(dlib.vector(win_l3))
    data_pair.nonrelevant.append(dlib.vector(los_l3))
    queries_val_l3.append(data_pair)

print("2")
for win_l2, los_l2 in zip(win_set_val[win_set_val.columns[1]],los_set_val[los_set_val.columns[1]]):
    data_pair = dlib.ranking_pair()
    shape_feat = win_l2.shape[1]
    win_l2 = win_l2.reshape(shape_feat,1)
    los_l2 = los_l2.reshape(shape_feat,1)
    data_pair.relevant.append(dlib.vector(win_l2))
    data_pair.nonrelevant.append(dlib.vector(los_l2))
    queries_val_l2.append(data_pair)    
    
print("1")
    
for win_l1, los_l1 in zip(win_set_val[win_set_val.columns[2]],los_set_val[los_set_val.columns[2]]):
    data_pair = dlib.ranking_pair()
    shape_feat = win_l1.shape[1]
    win_l1 = win_l1.reshape(shape_feat,1)
    los_l1 = los_l1.reshape(shape_feat,1)
    data_pair.relevant.append(dlib.vector(win_l1))
    data_pair.nonrelevant.append(dlib.vector(los_l1))
    queries_val_l1.append(data_pair)
# Out:
# 3
# 2
# 1
# TEST
# 3
# 2
# 1
# val
# 3
# 2
# 1
# CPU times: user 1min 1s, sys: 1.44 s, total: 1min 2s
# Wall time: 1min 3s

# %%
trainer_l3 = dlib.svm_rank_trainer()
trainer_l3.c = 1
rank_l3 = trainer_l3.train(queries_train_l3)
print("TRAIN ACCURACY",dlib.test_ranking_function(rank_l3, queries_train_l3))
print("VAL ACCURACY",dlib.test_ranking_function(rank_l3, queries_val_l3))
# Out:
# TRAIN ACCURACY ranking_accuracy: 0.697015  mean_ap: 0.848508
# VAL ACCURACY ranking_accuracy: 0.698234  mean_ap: 0.849117

# %%
print("TEST ACCURACY", dlib.test_ranking_function(rank_l3, queries_test_l3))
# Out:
# TEST ACCURACY ranking_accuracy: 0.67926  mean_ap: 0.83963

# %%
trainer_l2 = dlib.svm_rank_trainer()
trainer_l2.c = 1
rank_l2 = trainer_l2.train(queries_train_l2)
print("TRAIN ACCURACY",dlib.test_ranking_function(rank_l2, queries_train_l2))
print("VAL ACCURACY", dlib.test_ranking_function(rank_l2, queries_val_l2))
# Out:
# TRAIN ACCURACY ranking_accuracy: 0.69373  mean_ap: 0.846865
# TEST ACCURACY ranking_accuracy: 0.680578  mean_ap: 0.840289

# %%
print("TEST ACCURACY", dlib.test_ranking_function(rank_l2, queries_test_l2))
# Out:
# TEST ACCURACY ranking_accuracy: 0.66881  mean_ap: 0.834405

# %%
trainer_l1 = dlib.svm_rank_trainer()
trainer_l1.c = 1
rank_l1 = trainer_l1.train(queries_train_l1)
print("TRAIN ACCURACY",dlib.test_ranking_function(rank_l1, queries_train_l1))
print("VAL ACCURACY", dlib.test_ranking_function(rank_l1, queries_val_l1))
# Out:
# TRAIN ACCURACY ranking_accuracy: 0.696546  mean_ap: 0.848273
# VAL ACCURACY ranking_accuracy: 0.693419  mean_ap: 0.846709

# %%
print("TEST ACCURACY", dlib.test_ranking_function(rank_l1, queries_test_l1))
# Out:
# TEST ACCURACY ranking_accuracy: 0.696141  mean_ap: 0.848071
